# %% [markdown]
# **Dueling DQN:**
#
# In this code, we implement the Dueling Deep Q-learning (Dueling-DQN) algorithm on MountainCar-v0 environment.
#
# The details of the algorithm can be found here:
#
# **Dueling Network Architectures for Deep Reinforcement Learning**
#
# https://arxiv.org/pdf/1511.06581

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
import gym
import random
from collections import namedtuple

import warnings
#warnings.simplefilter("error")
warnings.simplefilter("ignore", UserWarning)

Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward', 'done'))

TARGET_UPDATE = 5
num_episodes = 1000
hidden = 128
gamma = 0.99
replay_buffer_size = 100000
batch_size = 30
eps_stop = 0.1
epsilon = 0.5
eps = 0.4
Start_epsilon_decaying=0
End_epsilon_decaying=num_episodes//2
epsilon_decaying= epsilon/(End_epsilon_decaying-Start_epsilon_decaying)


class ReplayMemory(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """Saves a transition."""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)


class DuelingDQN(nn.Module):
    def __init__(self, state_space_dim, action_space_dim, hidden):
        super(DuelingDQN, self).__init__()
        #self.hidden = hidden
        #self.fc1 = nn.Linear(state_space_dim, hidden)
        #self.fc2 = nn.Linear(hidden, hidden) #Now, we have features
        self.Value_stream_l1 = nn.Linear(state_space_dim, hidden)
        self.Value_stream_l2 = nn.Linear(hidden, 1)
        self.Advantage_stream_l1 = nn.Linear(state_space_dim, hidden)
        self.Advantage_stream_l2 = nn.Linear(hidden, action_space_dim)

    def forward(self, x):
        #x = F.relu(self.fc1(x))
        #x = F.relu(self.fc2(x))
        y = F.relu(self.Value_stream_l1(x))
        value = self.Value_stream_l2(y)
        z = F.relu(self.Advantage_stream_l1(x))
        advantages = self.Advantage_stream_l2(z)
        qvals = value + (advantages - advantages.mean())
        #print(qvals)
        return qvals


class DuelingDQNAgent(object):
    def __init__(self, state_space, n_actions, replay_buffer_size,
                 batch_size, hidden_size, gamma):
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.n_actions = n_actions
        self.state_space_dim = state_space
        self.policy_net = DuelingDQN(state_space, n_actions, hidden_size).to(self.device)
        self.target_net = DuelingDQN(state_space, n_actions, hidden_size).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=1e-3)
        self.memory = ReplayMemory(replay_buffer_size)
        self.batch_size = batch_size
        self.gamma = gamma

    def update_network(self, updates=1):
        for _ in range(updates):
            self._do_network_update()

    def _do_network_update(self):
        if len(self.memory) < self.batch_size:
            return
        transitions = self.memory.sample(self.batch_size)
        batch = Transition(*zip(*transitions))

        non_final_mask = 1 - torch.tensor(batch.done, dtype=torch.uint8)
        non_final_next_states = [s for nonfinal, s in zip(non_final_mask,
                                                          batch.next_state) if nonfinal > 0]
        non_final_next_states = torch.stack(non_final_next_states).to(self.device)
        state_batch = torch.stack(batch.state).to(self.device)
        action_batch = torch.cat(batch.action).to(self.device)
        reward_batch = torch.cat(batch.reward).to(self.device)

        self.optimizer.zero_grad()
        state_action_values = self.policy_net(state_batch).gather(1, action_batch)

        next_state_values = torch.zeros(self.batch_size).to(self.device)
        next_state_values[non_final_mask] = self.target_net(non_final_next_states).max(1)[0].detach()
        expected_state_action_values = reward_batch + self.gamma * next_state_values

        # Compute Huber loss
        loss = F.smooth_l1_loss(state_action_values.squeeze(),
                                expected_state_action_values)

        # Optimize the model
        loss.backward()
        for param in self.policy_net.parameters():
            param.grad.data.clamp_(-1e-1, 1e-1)
        self.optimizer.step()

    def get_action(self, state, epsilon):
        sample = random.random()
        if sample > epsilon:
            with torch.no_grad():
                state = torch.from_numpy(state).float().to(self.device)
                q_values = self.policy_net(state).to(self.device)
                return torch.argmax(q_values).item()
        else:
            return random.randrange(self.n_actions)

    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

    def store_transition(self, state, action, next_state, reward, done):
        action = torch.Tensor([[action]]).long()
        reward = torch.tensor([reward], dtype=torch.float32)
        next_state = torch.from_numpy(next_state).float()
        state = torch.from_numpy(state).float()
        self.memory.push(state, action, next_state, reward, done)

env = gym.make("MountainCar-v0")
env.reset()
n_actions = env.action_space.n
state_space_dim = env.observation_space.shape[0]
#print(state_space_dim)
agent = DuelingDQNAgent(state_space_dim, n_actions, replay_buffer_size, batch_size,
                  hidden, gamma)

# Training loop
cumulative_rewards = []
counter_reach_goal = 0
last100_rewards = [-200 for _ in range(100) ] 
positions = []
for ep in range(num_episodes):
    # Initialize the environment and state
    #print('training started ...')
    state = env.reset()
    done = False
    eps -= epsilon_decaying
    epsilon = max(0.05 , eps)
    cum_reward = 0
    
    while not done:
        #if ep % 100 == 0:
            #env.render()
        # Select and perform an action
        action = agent.get_action(state, epsilon)
        next_state, reward, done, _ = env.step(action)
        cum_reward += reward

        agent.store_transition(state, action, next_state, reward, done)
        agent.update_network()

        # Move to the next state
        state = next_state

    positions.append(state[0])
    cumulative_rewards.append(cum_reward)
    if ep >= 100:
        last100_rewards.append(np.mean(cumulative_rewards[ep - 100:ep]))
    print("episode: %d: reward: %6.2f, mean_100: %6.2f, epsilon: %.2f" % (
        ep, cum_reward, np.mean(cumulative_rewards[-100:]), epsilon))

    if np.mean(cumulative_rewards[-100:]) > 195.0:
    #    print("Solved in ep : {} and break".format(ep))
        break

    # Update the target network, copying all weights and biases in DQN
    if ep % TARGET_UPDATE == 0:
        agent.update_target_network()
    
#env.close()
plt.plot(range(num_episodes),cumulative_rewards,label='cumulative rewards', color = 'b')
plt.plot(range(num_episodes),last100_rewards,label='last 100 episodes', color = 'r')
plt.legend(loc = 2)
plt.show()
plt.plot(range(num_episodes),positions,label='Final position of the car (x)', color = 'b')
plt.legend(loc = 2)
plt.show()
#print('Complete')
# Out:
# episode: 0: reward: -200.00, mean_100: -200.00, epsilon: 0.40
# episode: 1: reward: -200.00, mean_100: -200.00, epsilon: 0.40
# episode: 2: reward: -200.00, mean_100: -200.00, epsilon: 0.40
# episode: 3: reward: -200.00, mean_100: -200.00, epsilon: 0.40
# episode: 4: reward: -200.00, mean_100: -200.00, epsilon: 0.40
# episode: 5: reward: -200.00, mean_100: -200.00, epsilon: 0.39
# episode: 6: reward: -200.00, mean_100: -200.00, epsilon: 0.39
# episode: 7: reward: -200.00, mean_100: -200.00, epsilon: 0.39
# episode: 8: reward: -200.00, mean_100: -200.00, epsilon: 0.39
# episode: 9: reward: -200.00, mean_100: -200.00, epsilon: 0.39
# episode: 10: reward: -200.00, mean_100: -200.00, epsilon: 0.39
# episode: 11: reward: -200.00, mean_100: -200.00, epsilon: 0.39
# episode: 12: reward: -200.00, mean_100: -200.00, epsilon: 0.39
# episode: 13: reward: -200.00, mean_100: -200.00, epsilon: 0.39
# episode: 14: reward: -200.00, mean_100: -200.00, epsilon: 0.39
# episode: 15: reward: -200.00, mean_100: -200.00, epsilon: 0.38
# episode: 16: reward: -200.00, mean_100: -200.00, epsilon: 0.38
# episode: 17: reward: -200.00, mean_100: -200.00, epsilon: 0.38
# episode: 18: reward: -200.00, mean_100: -200.00, epsilon: 0.38
# episode: 19: reward: -200.00, mean_100: -200.00, epsilon: 0.38
# episode: 20: reward: -200.00, mean_100: -200.00, epsilon: 0.38
# episode: 21: reward: -200.00, mean_100: -200.00, epsilon: 0.38
# episode: 22: reward: -200.00, mean_100: -200.00, epsilon: 0.38
# episode: 23: reward: -200.00, mean_100: -200.00, epsilon: 0.38
# episode: 24: reward: -200.00, mean_100: -200.00, epsilon: 0.38
# episode: 25: reward: -200.00, mean_100: -200.00, epsilon: 0.37
# episode: 26: reward: -200.00, mean_100: -200.00, epsilon: 0.37
# episode: 27: reward: -200.00, mean_100: -200.00, epsilon: 0.37
# episode: 28: reward: -200.00, mean_100: -200.00, epsilon: 0.37
# episode: 29: reward: -200.00, mean_100: -200.00, epsilon: 0.37
# episode: 30: reward: -200.00, mean_100: -200.00, epsilon: 0.37
# episode: 31: reward: -200.00, mean_100: -200.00, epsilon: 0.37
# episode: 32: reward: -200.00, mean_100: -200.00, epsilon: 0.37
# episode: 33: reward: -200.00, mean_100: -200.00, epsilon: 0.37
# episode: 34: reward: -200.00, mean_100: -200.00, epsilon: 0.36
# episode: 35: reward: -200.00, mean_100: -200.00, epsilon: 0.36
# episode: 36: reward: -200.00, mean_100: -200.00, epsilon: 0.36
# episode: 37: reward: -200.00, mean_100: -200.00, epsilon: 0.36
# episode: 38: reward: -200.00, mean_100: -200.00, epsilon: 0.36
# episode: 39: reward: -200.00, mean_100: -200.00, epsilon: 0.36
# episode: 40: reward: -200.00, mean_100: -200.00, epsilon: 0.36
# episode: 41: reward: -200.00, mean_100: -200.00, epsilon: 0.36
# episode: 42: reward: -200.00, mean_100: -200.00, epsilon: 0.36
# episode: 43: reward: -200.00, mean_100: -200.00, epsilon: 0.36
# episode: 44: reward: -200.00, mean_100: -200.00, epsilon: 0.35
# episode: 45: reward: -200.00, mean_100: -200.00, epsilon: 0.35
# episode: 46: reward: -200.00, mean_100: -200.00, epsilon: 0.35
# episode: 47: reward: -200.00, mean_100: -200.00, epsilon: 0.35
# episode: 48: reward: -200.00, mean_100: -200.00, epsilon: 0.35
# episode: 49: reward: -200.00, mean_100: -200.00, epsilon: 0.35
# episode: 50: reward: -200.00, mean_100: -200.00, epsilon: 0.35
# episode: 51: reward: -200.00, mean_100: -200.00, epsilon: 0.35
# episode: 52: reward: -200.00, mean_100: -200.00, epsilon: 0.35
# episode: 53: reward: -200.00, mean_100: -200.00, epsilon: 0.35
# episode: 54: reward: -200.00, mean_100: -200.00, epsilon: 0.34
# episode: 55: reward: -200.00, mean_100: -200.00, epsilon: 0.34
# episode: 56: reward: -200.00, mean_100: -200.00, epsilon: 0.34
# episode: 57: reward: -200.00, mean_100: -200.00, epsilon: 0.34
# episode: 58: reward: -200.00, mean_100: -200.00, epsilon: 0.34
# episode: 59: reward: -200.00, mean_100: -200.00, epsilon: 0.34
# episode: 60: reward: -200.00, mean_100: -200.00, epsilon: 0.34
# episode: 61: reward: -200.00, mean_100: -200.00, epsilon: 0.34
# episode: 62: reward: -200.00, mean_100: -200.00, epsilon: 0.34
# episode: 63: reward: -200.00, mean_100: -200.00, epsilon: 0.34
# episode: 64: reward: -200.00, mean_100: -200.00, epsilon: 0.33
# episode: 65: reward: -200.00, mean_100: -200.00, epsilon: 0.33
# episode: 66: reward: -200.00, mean_100: -200.00, epsilon: 0.33
# episode: 67: reward: -200.00, mean_100: -200.00, epsilon: 0.33
# episode: 68: reward: -200.00, mean_100: -200.00, epsilon: 0.33
# episode: 69: reward: -200.00, mean_100: -200.00, epsilon: 0.33
# episode: 70: reward: -200.00, mean_100: -200.00, epsilon: 0.33
# episode: 71: reward: -200.00, mean_100: -200.00, epsilon: 0.33
# episode: 72: reward: -200.00, mean_100: -200.00, epsilon: 0.33
# episode: 73: reward: -200.00, mean_100: -200.00, epsilon: 0.33
# episode: 74: reward: -200.00, mean_100: -200.00, epsilon: 0.32
# episode: 75: reward: -200.00, mean_100: -200.00, epsilon: 0.32
# episode: 76: reward: -200.00, mean_100: -200.00, epsilon: 0.32
# episode: 77: reward: -200.00, mean_100: -200.00, epsilon: 0.32
# episode: 78: reward: -200.00, mean_100: -200.00, epsilon: 0.32
# episode: 79: reward: -200.00, mean_100: -200.00, epsilon: 0.32
# episode: 80: reward: -200.00, mean_100: -200.00, epsilon: 0.32
# episode: 81: reward: -200.00, mean_100: -200.00, epsilon: 0.32
# episode: 82: reward: -200.00, mean_100: -200.00, epsilon: 0.32
# episode: 83: reward: -200.00, mean_100: -200.00, epsilon: 0.32
# episode: 84: reward: -200.00, mean_100: -200.00, epsilon: 0.31
# episode: 85: reward: -200.00, mean_100: -200.00, epsilon: 0.31
# episode: 86: reward: -200.00, mean_100: -200.00, epsilon: 0.31
# episode: 87: reward: -200.00, mean_100: -200.00, epsilon: 0.31
# episode: 88: reward: -200.00, mean_100: -200.00, epsilon: 0.31
# episode: 89: reward: -200.00, mean_100: -200.00, epsilon: 0.31
# episode: 90: reward: -200.00, mean_100: -200.00, epsilon: 0.31
# episode: 91: reward: -200.00, mean_100: -200.00, epsilon: 0.31
# episode: 92: reward: -200.00, mean_100: -200.00, epsilon: 0.31
# episode: 93: reward: -200.00, mean_100: -200.00, epsilon: 0.31
# episode: 94: reward: -200.00, mean_100: -200.00, epsilon: 0.30
# episode: 95: reward: -200.00, mean_100: -200.00, epsilon: 0.30
# episode: 96: reward: -200.00, mean_100: -200.00, epsilon: 0.30
# episode: 97: reward: -200.00, mean_100: -200.00, epsilon: 0.30
# episode: 98: reward: -200.00, mean_100: -200.00, epsilon: 0.30
# episode: 99: reward: -200.00, mean_100: -200.00, epsilon: 0.30
# episode: 100: reward: -200.00, mean_100: -200.00, epsilon: 0.30
# episode: 101: reward: -200.00, mean_100: -200.00, epsilon: 0.30
# episode: 102: reward: -200.00, mean_100: -200.00, epsilon: 0.30
# episode: 103: reward: -200.00, mean_100: -200.00, epsilon: 0.30
# episode: 104: reward: -200.00, mean_100: -200.00, epsilon: 0.29
# episode: 105: reward: -200.00, mean_100: -200.00, epsilon: 0.29
# episode: 106: reward: -200.00, mean_100: -200.00, epsilon: 0.29
# episode: 107: reward: -200.00, mean_100: -200.00, epsilon: 0.29
# episode: 108: reward: -200.00, mean_100: -200.00, epsilon: 0.29
# episode: 109: reward: -200.00, mean_100: -200.00, epsilon: 0.29
# episode: 110: reward: -200.00, mean_100: -200.00, epsilon: 0.29
# episode: 111: reward: -200.00, mean_100: -200.00, epsilon: 0.29
# episode: 112: reward: -200.00, mean_100: -200.00, epsilon: 0.29
# episode: 113: reward: -200.00, mean_100: -200.00, epsilon: 0.29
# episode: 114: reward: -200.00, mean_100: -200.00, epsilon: 0.28
# episode: 115: reward: -200.00, mean_100: -200.00, epsilon: 0.28
# episode: 116: reward: -200.00, mean_100: -200.00, epsilon: 0.28
# episode: 117: reward: -200.00, mean_100: -200.00, epsilon: 0.28
# episode: 118: reward: -200.00, mean_100: -200.00, epsilon: 0.28
# episode: 119: reward: -200.00, mean_100: -200.00, epsilon: 0.28
# episode: 120: reward: -200.00, mean_100: -200.00, epsilon: 0.28
# episode: 121: reward: -200.00, mean_100: -200.00, epsilon: 0.28
# episode: 122: reward: -200.00, mean_100: -200.00, epsilon: 0.28
# episode: 123: reward: -200.00, mean_100: -200.00, epsilon: 0.28
# episode: 124: reward: -200.00, mean_100: -200.00, epsilon: 0.27
# episode: 125: reward: -200.00, mean_100: -200.00, epsilon: 0.27
# episode: 126: reward: -200.00, mean_100: -200.00, epsilon: 0.27
# episode: 127: reward: -200.00, mean_100: -200.00, epsilon: 0.27
# episode: 128: reward: -200.00, mean_100: -200.00, epsilon: 0.27
# episode: 129: reward: -200.00, mean_100: -200.00, epsilon: 0.27
# episode: 130: reward: -200.00, mean_100: -200.00, epsilon: 0.27
# episode: 131: reward: -200.00, mean_100: -200.00, epsilon: 0.27
# episode: 132: reward: -200.00, mean_100: -200.00, epsilon: 0.27
# episode: 133: reward: -200.00, mean_100: -200.00, epsilon: 0.27
# episode: 134: reward: -200.00, mean_100: -200.00, epsilon: 0.26
# episode: 135: reward: -200.00, mean_100: -200.00, epsilon: 0.26
# episode: 136: reward: -200.00, mean_100: -200.00, epsilon: 0.26
# episode: 137: reward: -200.00, mean_100: -200.00, epsilon: 0.26
# episode: 138: reward: -200.00, mean_100: -200.00, epsilon: 0.26
# episode: 139: reward: -200.00, mean_100: -200.00, epsilon: 0.26
# episode: 140: reward: -200.00, mean_100: -200.00, epsilon: 0.26
# episode: 141: reward: -200.00, mean_100: -200.00, epsilon: 0.26
# episode: 142: reward: -200.00, mean_100: -200.00, epsilon: 0.26
# episode: 143: reward: -200.00, mean_100: -200.00, epsilon: 0.26
# episode: 144: reward: -200.00, mean_100: -200.00, epsilon: 0.25
# episode: 145: reward: -200.00, mean_100: -200.00, epsilon: 0.25
# episode: 146: reward: -200.00, mean_100: -200.00, epsilon: 0.25
# episode: 147: reward: -200.00, mean_100: -200.00, epsilon: 0.25
# episode: 148: reward: -200.00, mean_100: -200.00, epsilon: 0.25
# episode: 149: reward: -200.00, mean_100: -200.00, epsilon: 0.25
# episode: 150: reward: -200.00, mean_100: -200.00, epsilon: 0.25
# episode: 151: reward: -200.00, mean_100: -200.00, epsilon: 0.25
# episode: 152: reward: -200.00, mean_100: -200.00, epsilon: 0.25
# episode: 153: reward: -200.00, mean_100: -200.00, epsilon: 0.25
# episode: 154: reward: -200.00, mean_100: -200.00, epsilon: 0.24
# episode: 155: reward: -200.00, mean_100: -200.00, epsilon: 0.24
# episode: 156: reward: -200.00, mean_100: -200.00, epsilon: 0.24
# episode: 157: reward: -200.00, mean_100: -200.00, epsilon: 0.24
# episode: 158: reward: -200.00, mean_100: -200.00, epsilon: 0.24
# episode: 159: reward: -200.00, mean_100: -200.00, epsilon: 0.24
# episode: 160: reward: -200.00, mean_100: -200.00, epsilon: 0.24
# episode: 161: reward: -200.00, mean_100: -200.00, epsilon: 0.24
# episode: 162: reward: -200.00, mean_100: -200.00, epsilon: 0.24
# episode: 163: reward: -200.00, mean_100: -200.00, epsilon: 0.24
# episode: 164: reward: -200.00, mean_100: -200.00, epsilon: 0.23
# episode: 165: reward: -200.00, mean_100: -200.00, epsilon: 0.23
# episode: 166: reward: -200.00, mean_100: -200.00, epsilon: 0.23
# episode: 167: reward: -200.00, mean_100: -200.00, epsilon: 0.23
# episode: 168: reward: -200.00, mean_100: -200.00, epsilon: 0.23
# episode: 169: reward: -200.00, mean_100: -200.00, epsilon: 0.23
# episode: 170: reward: -200.00, mean_100: -200.00, epsilon: 0.23
# episode: 171: reward: -200.00, mean_100: -200.00, epsilon: 0.23
# episode: 172: reward: -200.00, mean_100: -200.00, epsilon: 0.23
# episode: 173: reward: -200.00, mean_100: -200.00, epsilon: 0.23
# episode: 174: reward: -200.00, mean_100: -200.00, epsilon: 0.22
# episode: 175: reward: -200.00, mean_100: -200.00, epsilon: 0.22
# episode: 176: reward: -200.00, mean_100: -200.00, epsilon: 0.22
# episode: 177: reward: -200.00, mean_100: -200.00, epsilon: 0.22
# episode: 178: reward: -200.00, mean_100: -200.00, epsilon: 0.22
# episode: 179: reward: -200.00, mean_100: -200.00, epsilon: 0.22
# episode: 180: reward: -200.00, mean_100: -200.00, epsilon: 0.22
# episode: 181: reward: -200.00, mean_100: -200.00, epsilon: 0.22
# episode: 182: reward: -200.00, mean_100: -200.00, epsilon: 0.22
# episode: 183: reward: -200.00, mean_100: -200.00, epsilon: 0.22
# episode: 184: reward: -200.00, mean_100: -200.00, epsilon: 0.21
# episode: 185: reward: -200.00, mean_100: -200.00, epsilon: 0.21
# episode: 186: reward: -200.00, mean_100: -200.00, epsilon: 0.21
# episode: 187: reward: -200.00, mean_100: -200.00, epsilon: 0.21
# episode: 188: reward: -200.00, mean_100: -200.00, epsilon: 0.21
# episode: 189: reward: -200.00, mean_100: -200.00, epsilon: 0.21
# episode: 190: reward: -200.00, mean_100: -200.00, epsilon: 0.21
# episode: 191: reward: -200.00, mean_100: -200.00, epsilon: 0.21
# episode: 192: reward: -200.00, mean_100: -200.00, epsilon: 0.21
# episode: 193: reward: -200.00, mean_100: -200.00, epsilon: 0.21
# episode: 194: reward: -200.00, mean_100: -200.00, epsilon: 0.20
# episode: 195: reward: -200.00, mean_100: -200.00, epsilon: 0.20
# episode: 196: reward: -200.00, mean_100: -200.00, epsilon: 0.20
# episode: 197: reward: -192.00, mean_100: -199.92, epsilon: 0.20
# episode: 198: reward: -200.00, mean_100: -199.92, epsilon: 0.20
# episode: 199: reward: -200.00, mean_100: -199.92, epsilon: 0.20
# episode: 200: reward: -200.00, mean_100: -199.92, epsilon: 0.20
# episode: 201: reward: -200.00, mean_100: -199.92, epsilon: 0.20
# episode: 202: reward: -200.00, mean_100: -199.92, epsilon: 0.20
# episode: 203: reward: -200.00, mean_100: -199.92, epsilon: 0.20
# episode: 204: reward: -200.00, mean_100: -199.92, epsilon: 0.19
# episode: 205: reward: -200.00, mean_100: -199.92, epsilon: 0.19
# episode: 206: reward: -200.00, mean_100: -199.92, epsilon: 0.19
# episode: 207: reward: -200.00, mean_100: -199.92, epsilon: 0.19
# episode: 208: reward: -200.00, mean_100: -199.92, epsilon: 0.19
# episode: 209: reward: -200.00, mean_100: -199.92, epsilon: 0.19
# episode: 210: reward: -200.00, mean_100: -199.92, epsilon: 0.19
# episode: 211: reward: -200.00, mean_100: -199.92, epsilon: 0.19
# episode: 212: reward: -200.00, mean_100: -199.92, epsilon: 0.19
# episode: 213: reward: -200.00, mean_100: -199.92, epsilon: 0.19
# episode: 214: reward: -200.00, mean_100: -199.92, epsilon: 0.18
# episode: 215: reward: -200.00, mean_100: -199.92, epsilon: 0.18
# episode: 216: reward: -200.00, mean_100: -199.92, epsilon: 0.18
# episode: 217: reward: -200.00, mean_100: -199.92, epsilon: 0.18
# episode: 218: reward: -200.00, mean_100: -199.92, epsilon: 0.18
# episode: 219: reward: -200.00, mean_100: -199.92, epsilon: 0.18
# episode: 220: reward: -177.00, mean_100: -199.69, epsilon: 0.18
# episode: 221: reward: -146.00, mean_100: -199.15, epsilon: 0.18
# episode: 222: reward: -200.00, mean_100: -199.15, epsilon: 0.18
# episode: 223: reward: -200.00, mean_100: -199.15, epsilon: 0.18
# episode: 224: reward: -185.00, mean_100: -199.00, epsilon: 0.17
# episode: 225: reward: -200.00, mean_100: -199.00, epsilon: 0.17
# episode: 226: reward: -200.00, mean_100: -199.00, epsilon: 0.17
# episode: 227: reward: -178.00, mean_100: -198.78, epsilon: 0.17
# episode: 228: reward: -200.00, mean_100: -198.78, epsilon: 0.17
# episode: 229: reward: -200.00, mean_100: -198.78, epsilon: 0.17
# episode: 230: reward: -162.00, mean_100: -198.40, epsilon: 0.17
# episode: 231: reward: -200.00, mean_100: -198.40, epsilon: 0.17
# episode: 232: reward: -200.00, mean_100: -198.40, epsilon: 0.17
# episode: 233: reward: -200.00, mean_100: -198.40, epsilon: 0.17
# episode: 234: reward: -200.00, mean_100: -198.40, epsilon: 0.16
# episode: 235: reward: -200.00, mean_100: -198.40, epsilon: 0.16
# episode: 236: reward: -200.00, mean_100: -198.40, epsilon: 0.16
# episode: 237: reward: -200.00, mean_100: -198.40, epsilon: 0.16
# episode: 238: reward: -150.00, mean_100: -197.90, epsilon: 0.16
# episode: 239: reward: -200.00, mean_100: -197.90, epsilon: 0.16
# episode: 240: reward: -200.00, mean_100: -197.90, epsilon: 0.16
# episode: 241: reward: -200.00, mean_100: -197.90, epsilon: 0.16
# episode: 242: reward: -200.00, mean_100: -197.90, epsilon: 0.16
# episode: 243: reward: -200.00, mean_100: -197.90, epsilon: 0.16
# episode: 244: reward: -167.00, mean_100: -197.57, epsilon: 0.15
# episode: 245: reward: -156.00, mean_100: -197.13, epsilon: 0.15
# episode: 246: reward: -187.00, mean_100: -197.00, epsilon: 0.15
# episode: 247: reward: -200.00, mean_100: -197.00, epsilon: 0.15
# episode: 248: reward: -166.00, mean_100: -196.66, epsilon: 0.15
# episode: 249: reward: -200.00, mean_100: -196.66, epsilon: 0.15
# episode: 250: reward: -181.00, mean_100: -196.47, epsilon: 0.15
# episode: 251: reward: -200.00, mean_100: -196.47, epsilon: 0.15
# episode: 252: reward: -173.00, mean_100: -196.20, epsilon: 0.15
# episode: 253: reward: -133.00, mean_100: -195.53, epsilon: 0.15
# episode: 254: reward: -172.00, mean_100: -195.25, epsilon: 0.14
# episode: 255: reward: -154.00, mean_100: -194.79, epsilon: 0.14
# episode: 256: reward: -200.00, mean_100: -194.79, epsilon: 0.14
# episode: 257: reward: -170.00, mean_100: -194.49, epsilon: 0.14
# episode: 258: reward: -200.00, mean_100: -194.49, epsilon: 0.14
# episode: 259: reward: -200.00, mean_100: -194.49, epsilon: 0.14
# episode: 260: reward: -200.00, mean_100: -194.49, epsilon: 0.14
# episode: 261: reward: -200.00, mean_100: -194.49, epsilon: 0.14
# episode: 262: reward: -200.00, mean_100: -194.49, epsilon: 0.14
# episode: 263: reward: -200.00, mean_100: -194.49, epsilon: 0.14
# episode: 264: reward: -174.00, mean_100: -194.23, epsilon: 0.13
# episode: 265: reward: -170.00, mean_100: -193.93, epsilon: 0.13
# episode: 266: reward: -200.00, mean_100: -193.93, epsilon: 0.13
# episode: 267: reward: -160.00, mean_100: -193.53, epsilon: 0.13
# episode: 268: reward: -200.00, mean_100: -193.53, epsilon: 0.13
# episode: 269: reward: -200.00, mean_100: -193.53, epsilon: 0.13
# episode: 270: reward: -119.00, mean_100: -192.72, epsilon: 0.13
# episode: 271: reward: -200.00, mean_100: -192.72, epsilon: 0.13
# episode: 272: reward: -173.00, mean_100: -192.45, epsilon: 0.13
# episode: 273: reward: -200.00, mean_100: -192.45, epsilon: 0.13
# episode: 274: reward: -193.00, mean_100: -192.38, epsilon: 0.12
# episode: 275: reward: -111.00, mean_100: -191.49, epsilon: 0.12
# episode: 276: reward: -200.00, mean_100: -191.49, epsilon: 0.12
# episode: 277: reward: -170.00, mean_100: -191.19, epsilon: 0.12
# episode: 278: reward: -146.00, mean_100: -190.65, epsilon: 0.12
# episode: 279: reward: -170.00, mean_100: -190.35, epsilon: 0.12
# episode: 280: reward: -200.00, mean_100: -190.35, epsilon: 0.12
# episode: 281: reward: -169.00, mean_100: -190.04, epsilon: 0.12
# episode: 282: reward: -200.00, mean_100: -190.04, epsilon: 0.12
# episode: 283: reward: -200.00, mean_100: -190.04, epsilon: 0.12
# episode: 284: reward: -200.00, mean_100: -190.04, epsilon: 0.11
# episode: 285: reward: -151.00, mean_100: -189.55, epsilon: 0.11
# episode: 286: reward: -138.00, mean_100: -188.93, epsilon: 0.11
# episode: 287: reward: -200.00, mean_100: -188.93, epsilon: 0.11
# episode: 288: reward: -123.00, mean_100: -188.16, epsilon: 0.11
# episode: 289: reward: -168.00, mean_100: -187.84, epsilon: 0.11
# episode: 290: reward: -156.00, mean_100: -187.40, epsilon: 0.11
# episode: 291: reward: -137.00, mean_100: -186.77, epsilon: 0.11
# episode: 292: reward: -125.00, mean_100: -186.02, epsilon: 0.11
# episode: 293: reward: -141.00, mean_100: -185.43, epsilon: 0.11
# episode: 294: reward: -159.00, mean_100: -185.02, epsilon: 0.10
# episode: 295: reward: -147.00, mean_100: -184.49, epsilon: 0.10
# episode: 296: reward: -148.00, mean_100: -183.97, epsilon: 0.10
# episode: 297: reward: -156.00, mean_100: -183.61, epsilon: 0.10
# episode: 298: reward: -107.00, mean_100: -182.68, epsilon: 0.10
# episode: 299: reward: -200.00, mean_100: -182.68, epsilon: 0.10
# episode: 300: reward: -162.00, mean_100: -182.30, epsilon: 0.10
# episode: 301: reward: -165.00, mean_100: -181.95, epsilon: 0.10
# episode: 302: reward: -120.00, mean_100: -181.15, epsilon: 0.10
# episode: 303: reward: -152.00, mean_100: -180.67, epsilon: 0.10
# episode: 304: reward: -165.00, mean_100: -180.32, epsilon: 0.09
# episode: 305: reward: -149.00, mean_100: -179.81, epsilon: 0.09
# episode: 306: reward: -124.00, mean_100: -179.05, epsilon: 0.09
# episode: 307: reward: -118.00, mean_100: -178.23, epsilon: 0.09
# episode: 308: reward: -179.00, mean_100: -178.02, epsilon: 0.09
# episode: 309: reward: -198.00, mean_100: -178.00, epsilon: 0.09
# episode: 310: reward: -155.00, mean_100: -177.55, epsilon: 0.09
# episode: 311: reward: -181.00, mean_100: -177.36, epsilon: 0.09
# episode: 312: reward: -150.00, mean_100: -176.86, epsilon: 0.09
# episode: 313: reward: -158.00, mean_100: -176.44, epsilon: 0.09
# episode: 314: reward: -146.00, mean_100: -175.90, epsilon: 0.08
# episode: 315: reward: -194.00, mean_100: -175.84, epsilon: 0.08
# episode: 316: reward: -156.00, mean_100: -175.40, epsilon: 0.08
# episode: 317: reward: -136.00, mean_100: -174.76, epsilon: 0.08
# episode: 318: reward: -154.00, mean_100: -174.30, epsilon: 0.08
# episode: 319: reward: -173.00, mean_100: -174.03, epsilon: 0.08
# episode: 320: reward: -157.00, mean_100: -173.83, epsilon: 0.08
# episode: 321: reward: -190.00, mean_100: -174.27, epsilon: 0.08
# episode: 322: reward: -138.00, mean_100: -173.65, epsilon: 0.08
# episode: 323: reward: -119.00, mean_100: -172.84, epsilon: 0.08
# episode: 324: reward: -177.00, mean_100: -172.76, epsilon: 0.07
# episode: 325: reward: -159.00, mean_100: -172.35, epsilon: 0.07
# episode: 326: reward: -121.00, mean_100: -171.56, epsilon: 0.07
# episode: 327: reward: -170.00, mean_100: -171.48, epsilon: 0.07
# episode: 328: reward: -138.00, mean_100: -170.86, epsilon: 0.07
# episode: 329: reward: -144.00, mean_100: -170.30, epsilon: 0.07
# episode: 330: reward: -125.00, mean_100: -169.93, epsilon: 0.07
# episode: 331: reward: -181.00, mean_100: -169.74, epsilon: 0.07
# episode: 332: reward: -176.00, mean_100: -169.50, epsilon: 0.07
# episode: 333: reward: -140.00, mean_100: -168.90, epsilon: 0.07
# episode: 334: reward: -115.00, mean_100: -168.05, epsilon: 0.06
# episode: 335: reward: -149.00, mean_100: -167.54, epsilon: 0.06
# episode: 336: reward: -172.00, mean_100: -167.26, epsilon: 0.06
# episode: 337: reward: -150.00, mean_100: -166.76, epsilon: 0.06
# episode: 338: reward: -158.00, mean_100: -166.84, epsilon: 0.06
# episode: 339: reward: -141.00, mean_100: -166.25, epsilon: 0.06
# episode: 340: reward: -154.00, mean_100: -165.79, epsilon: 0.06
# episode: 341: reward: -138.00, mean_100: -165.17, epsilon: 0.06
# episode: 342: reward: -138.00, mean_100: -164.55, epsilon: 0.06
# episode: 343: reward: -134.00, mean_100: -163.89, epsilon: 0.06
# episode: 344: reward: -200.00, mean_100: -164.22, epsilon: 0.05
# episode: 345: reward: -146.00, mean_100: -164.12, epsilon: 0.05
# episode: 346: reward: -195.00, mean_100: -164.20, epsilon: 0.05
# episode: 347: reward: -120.00, mean_100: -163.40, epsilon: 0.05
# episode: 348: reward: -118.00, mean_100: -162.92, epsilon: 0.05
# episode: 349: reward: -138.00, mean_100: -162.30, epsilon: 0.05
# episode: 350: reward: -150.00, mean_100: -161.99, epsilon: 0.05
# episode: 351: reward: -148.00, mean_100: -161.47, epsilon: 0.05
# episode: 352: reward: -121.00, mean_100: -160.95, epsilon: 0.05
# episode: 353: reward: -199.00, mean_100: -161.61, epsilon: 0.05
# episode: 354: reward: -111.00, mean_100: -161.00, epsilon: 0.05
# episode: 355: reward: -200.00, mean_100: -161.46, epsilon: 0.05
# episode: 356: reward: -200.00, mean_100: -161.46, epsilon: 0.05
# episode: 357: reward: -146.00, mean_100: -161.22, epsilon: 0.05
# episode: 358: reward: -143.00, mean_100: -160.65, epsilon: 0.05
# episode: 359: reward: -162.00, mean_100: -160.27, epsilon: 0.05
# episode: 360: reward: -119.00, mean_100: -159.46, epsilon: 0.05
# episode: 361: reward: -145.00, mean_100: -158.91, epsilon: 0.05
# episode: 362: reward: -143.00, mean_100: -158.34, epsilon: 0.05
# episode: 363: reward: -118.00, mean_100: -157.52, epsilon: 0.05
# episode: 364: reward: -180.00, mean_100: -157.58, epsilon: 0.05
# episode: 365: reward: -144.00, mean_100: -157.32, epsilon: 0.05
# episode: 366: reward: -195.00, mean_100: -157.27, epsilon: 0.05
# episode: 367: reward: -188.00, mean_100: -157.55, epsilon: 0.05
# episode: 368: reward: -167.00, mean_100: -157.22, epsilon: 0.05
# episode: 369: reward: -141.00, mean_100: -156.63, epsilon: 0.05
# episode: 370: reward: -136.00, mean_100: -156.80, epsilon: 0.05
# episode: 371: reward: -200.00, mean_100: -156.80, epsilon: 0.05
# episode: 372: reward: -122.00, mean_100: -156.29, epsilon: 0.05
# episode: 373: reward: -139.00, mean_100: -155.68, epsilon: 0.05
# episode: 374: reward: -182.00, mean_100: -155.57, epsilon: 0.05
# episode: 375: reward: -134.00, mean_100: -155.80, epsilon: 0.05
# episode: 376: reward: -174.00, mean_100: -155.54, epsilon: 0.05
# episode: 377: reward: -200.00, mean_100: -155.84, epsilon: 0.05
# episode: 378: reward: -200.00, mean_100: -156.38, epsilon: 0.05
# episode: 379: reward: -190.00, mean_100: -156.58, epsilon: 0.05
# episode: 380: reward: -198.00, mean_100: -156.56, epsilon: 0.05
# episode: 381: reward: -172.00, mean_100: -156.59, epsilon: 0.05
# episode: 382: reward: -119.00, mean_100: -155.78, epsilon: 0.05
# episode: 383: reward: -113.00, mean_100: -154.91, epsilon: 0.05
# episode: 384: reward: -200.00, mean_100: -154.91, epsilon: 0.05
# episode: 385: reward: -120.00, mean_100: -154.60, epsilon: 0.05
# episode: 386: reward: -131.00, mean_100: -154.53, epsilon: 0.05
# episode: 387: reward: -168.00, mean_100: -154.21, epsilon: 0.05
# episode: 388: reward: -186.00, mean_100: -154.84, epsilon: 0.05
# episode: 389: reward: -118.00, mean_100: -154.34, epsilon: 0.05
# episode: 390: reward: -174.00, mean_100: -154.52, epsilon: 0.05
# episode: 391: reward: -137.00, mean_100: -154.52, epsilon: 0.05
# episode: 392: reward: -200.00, mean_100: -155.27, epsilon: 0.05
# episode: 393: reward: -114.00, mean_100: -155.00, epsilon: 0.05
# episode: 394: reward: -122.00, mean_100: -154.63, epsilon: 0.05
# episode: 395: reward: -113.00, mean_100: -154.29, epsilon: 0.05
# episode: 396: reward: -111.00, mean_100: -153.92, epsilon: 0.05
# episode: 397: reward: -199.00, mean_100: -154.35, epsilon: 0.05
# episode: 398: reward: -200.00, mean_100: -155.28, epsilon: 0.05
# episode: 399: reward: -148.00, mean_100: -154.76, epsilon: 0.05
# episode: 400: reward: -109.00, mean_100: -154.23, epsilon: 0.05
# episode: 401: reward: -147.00, mean_100: -154.05, epsilon: 0.05
# episode: 402: reward: -118.00, mean_100: -154.03, epsilon: 0.05
# episode: 403: reward: -200.00, mean_100: -154.51, epsilon: 0.05
# episode: 404: reward: -117.00, mean_100: -154.03, epsilon: 0.05
# episode: 405: reward: -115.00, mean_100: -153.69, epsilon: 0.05
# episode: 406: reward: -188.00, mean_100: -154.33, epsilon: 0.05
# episode: 407: reward: -200.00, mean_100: -155.15, epsilon: 0.05
# episode: 408: reward: -162.00, mean_100: -154.98, epsilon: 0.05
# episode: 409: reward: -153.00, mean_100: -154.53, epsilon: 0.05
# episode: 410: reward: -115.00, mean_100: -154.13, epsilon: 0.05
# episode: 411: reward: -200.00, mean_100: -154.32, epsilon: 0.05
# episode: 412: reward: -113.00, mean_100: -153.95, epsilon: 0.05
# episode: 413: reward: -197.00, mean_100: -154.34, epsilon: 0.05
# episode: 414: reward: -190.00, mean_100: -154.78, epsilon: 0.05
# episode: 415: reward: -115.00, mean_100: -153.99, epsilon: 0.05
# episode: 416: reward: -200.00, mean_100: -154.43, epsilon: 0.05
# episode: 417: reward: -118.00, mean_100: -154.25, epsilon: 0.05
# episode: 418: reward: -133.00, mean_100: -154.04, epsilon: 0.05
# episode: 419: reward: -177.00, mean_100: -154.08, epsilon: 0.05
# episode: 420: reward: -149.00, mean_100: -154.00, epsilon: 0.05
# episode: 421: reward: -163.00, mean_100: -153.73, epsilon: 0.05
# episode: 422: reward: -116.00, mean_100: -153.51, epsilon: 0.05
# episode: 423: reward: -118.00, mean_100: -153.50, epsilon: 0.05
# episode: 424: reward: -138.00, mean_100: -153.11, epsilon: 0.05
# episode: 425: reward: -113.00, mean_100: -152.65, epsilon: 0.05
# episode: 426: reward: -116.00, mean_100: -152.60, epsilon: 0.05
# episode: 427: reward: -153.00, mean_100: -152.43, epsilon: 0.05
# episode: 428: reward: -162.00, mean_100: -152.67, epsilon: 0.05
# episode: 429: reward: -122.00, mean_100: -152.45, epsilon: 0.05
# episode: 430: reward: -139.00, mean_100: -152.59, epsilon: 0.05
# episode: 431: reward: -151.00, mean_100: -152.29, epsilon: 0.05
# episode: 432: reward: -172.00, mean_100: -152.25, epsilon: 0.05
# episode: 433: reward: -200.00, mean_100: -152.85, epsilon: 0.05
# episode: 434: reward: -151.00, mean_100: -153.21, epsilon: 0.05
# episode: 435: reward: -146.00, mean_100: -153.18, epsilon: 0.05
# episode: 436: reward: -90.00, mean_100: -152.36, epsilon: 0.05
# episode: 437: reward: -190.00, mean_100: -152.76, epsilon: 0.05
# episode: 438: reward: -164.00, mean_100: -152.82, epsilon: 0.05
# episode: 439: reward: -146.00, mean_100: -152.87, epsilon: 0.05
# episode: 440: reward: -176.00, mean_100: -153.09, epsilon: 0.05
# episode: 441: reward: -187.00, mean_100: -153.58, epsilon: 0.05
# episode: 442: reward: -174.00, mean_100: -153.94, epsilon: 0.05
# episode: 443: reward: -163.00, mean_100: -154.23, epsilon: 0.05
# episode: 444: reward: -165.00, mean_100: -153.88, epsilon: 0.05
# episode: 445: reward: -143.00, mean_100: -153.85, epsilon: 0.05
# episode: 446: reward: -97.00, mean_100: -152.87, epsilon: 0.05
# episode: 447: reward: -91.00, mean_100: -152.58, epsilon: 0.05
# episode: 448: reward: -200.00, mean_100: -153.40, epsilon: 0.05
# episode: 449: reward: -100.00, mean_100: -153.02, epsilon: 0.05
# episode: 450: reward: -144.00, mean_100: -152.96, epsilon: 0.05
# episode: 451: reward: -180.00, mean_100: -153.28, epsilon: 0.05
# episode: 452: reward: -89.00, mean_100: -152.96, epsilon: 0.05
# episode: 453: reward: -139.00, mean_100: -152.36, epsilon: 0.05
# episode: 454: reward: -200.00, mean_100: -153.25, epsilon: 0.05
# episode: 455: reward: -99.00, mean_100: -152.24, epsilon: 0.05
# episode: 456: reward: -191.00, mean_100: -152.15, epsilon: 0.05
# episode: 457: reward: -144.00, mean_100: -152.13, epsilon: 0.05
# episode: 458: reward: -111.00, mean_100: -151.81, epsilon: 0.05
# episode: 459: reward: -121.00, mean_100: -151.40, epsilon: 0.05
# episode: 460: reward: -196.00, mean_100: -152.17, epsilon: 0.05
# episode: 461: reward: -167.00, mean_100: -152.39, epsilon: 0.05
# episode: 462: reward: -164.00, mean_100: -152.60, epsilon: 0.05
# episode: 463: reward: -176.00, mean_100: -153.18, epsilon: 0.05
# episode: 464: reward: -165.00, mean_100: -153.03, epsilon: 0.05
# episode: 465: reward: -91.00, mean_100: -152.50, epsilon: 0.05
# episode: 466: reward: -129.00, mean_100: -151.84, epsilon: 0.05
# episode: 467: reward: -156.00, mean_100: -151.52, epsilon: 0.05
# episode: 468: reward: -156.00, mean_100: -151.41, epsilon: 0.05
# episode: 469: reward: -167.00, mean_100: -151.67, epsilon: 0.05
# episode: 470: reward: -190.00, mean_100: -152.21, epsilon: 0.05
# episode: 471: reward: -93.00, mean_100: -151.14, epsilon: 0.05
# episode: 472: reward: -156.00, mean_100: -151.48, epsilon: 0.05
# episode: 473: reward: -155.00, mean_100: -151.64, epsilon: 0.05
# episode: 474: reward: -182.00, mean_100: -151.64, epsilon: 0.05
# episode: 475: reward: -161.00, mean_100: -151.91, epsilon: 0.05
# episode: 476: reward: -155.00, mean_100: -151.72, epsilon: 0.05
# episode: 477: reward: -91.00, mean_100: -150.63, epsilon: 0.05
# episode: 478: reward: -157.00, mean_100: -150.20, epsilon: 0.05
# episode: 479: reward: -170.00, mean_100: -150.00, epsilon: 0.05
# episode: 480: reward: -87.00, mean_100: -148.89, epsilon: 0.05
# episode: 481: reward: -158.00, mean_100: -148.75, epsilon: 0.05
# episode: 482: reward: -163.00, mean_100: -149.19, epsilon: 0.05
# episode: 483: reward: -200.00, mean_100: -150.06, epsilon: 0.05
# episode: 484: reward: -89.00, mean_100: -148.95, epsilon: 0.05
# episode: 485: reward: -159.00, mean_100: -149.34, epsilon: 0.05
# episode: 486: reward: -166.00, mean_100: -149.69, epsilon: 0.05
# episode: 487: reward: -156.00, mean_100: -149.57, epsilon: 0.05
# episode: 488: reward: -165.00, mean_100: -149.36, epsilon: 0.05
# episode: 489: reward: -157.00, mean_100: -149.75, epsilon: 0.05
# episode: 490: reward: -167.00, mean_100: -149.68, epsilon: 0.05
# episode: 491: reward: -87.00, mean_100: -149.18, epsilon: 0.05
# episode: 492: reward: -160.00, mean_100: -148.78, epsilon: 0.05
# episode: 493: reward: -141.00, mean_100: -149.05, epsilon: 0.05
# episode: 494: reward: -148.00, mean_100: -149.31, epsilon: 0.05
# episode: 495: reward: -92.00, mean_100: -149.10, epsilon: 0.05
# episode: 496: reward: -161.00, mean_100: -149.60, epsilon: 0.05
# episode: 497: reward: -153.00, mean_100: -149.14, epsilon: 0.05
# episode: 498: reward: -150.00, mean_100: -148.64, epsilon: 0.05
# episode: 499: reward: -88.00, mean_100: -148.04, epsilon: 0.05
# episode: 500: reward: -199.00, mean_100: -148.94, epsilon: 0.05
# episode: 501: reward: -180.00, mean_100: -149.27, epsilon: 0.05
# episode: 502: reward: -87.00, mean_100: -148.96, epsilon: 0.05
# episode: 503: reward: -155.00, mean_100: -148.51, epsilon: 0.05
# episode: 504: reward: -163.00, mean_100: -148.97, epsilon: 0.05
# episode: 505: reward: -160.00, mean_100: -149.42, epsilon: 0.05
# episode: 506: reward: -154.00, mean_100: -149.08, epsilon: 0.05
# episode: 507: reward: -91.00, mean_100: -147.99, epsilon: 0.05
# episode: 508: reward: -152.00, mean_100: -147.89, epsilon: 0.05
# episode: 509: reward: -152.00, mean_100: -147.88, epsilon: 0.05
# episode: 510: reward: -151.00, mean_100: -148.24, epsilon: 0.05
# episode: 511: reward: -157.00, mean_100: -147.81, epsilon: 0.05
# episode: 512: reward: -93.00, mean_100: -147.61, epsilon: 0.05
# episode: 513: reward: -148.00, mean_100: -147.12, epsilon: 0.05
# episode: 514: reward: -94.00, mean_100: -146.16, epsilon: 0.05
# episode: 515: reward: -148.00, mean_100: -146.49, epsilon: 0.05
# episode: 516: reward: -163.00, mean_100: -146.12, epsilon: 0.05
# episode: 517: reward: -147.00, mean_100: -146.41, epsilon: 0.05
# episode: 518: reward: -145.00, mean_100: -146.53, epsilon: 0.05
# episode: 519: reward: -170.00, mean_100: -146.46, epsilon: 0.05
# episode: 520: reward: -157.00, mean_100: -146.54, epsilon: 0.05
# episode: 521: reward: -88.00, mean_100: -145.79, epsilon: 0.05
# episode: 522: reward: -91.00, mean_100: -145.54, epsilon: 0.05
# episode: 523: reward: -150.00, mean_100: -145.86, epsilon: 0.05
# episode: 524: reward: -93.00, mean_100: -145.41, epsilon: 0.05
# episode: 525: reward: -89.00, mean_100: -145.17, epsilon: 0.05
# episode: 526: reward: -168.00, mean_100: -145.69, epsilon: 0.05
# episode: 527: reward: -155.00, mean_100: -145.71, epsilon: 0.05
# episode: 528: reward: -139.00, mean_100: -145.48, epsilon: 0.05
# episode: 529: reward: -89.00, mean_100: -145.15, epsilon: 0.05
# episode: 530: reward: -98.00, mean_100: -144.74, epsilon: 0.05
# episode: 531: reward: -159.00, mean_100: -144.82, epsilon: 0.05
# episode: 532: reward: -145.00, mean_100: -144.55, epsilon: 0.05
# episode: 533: reward: -92.00, mean_100: -143.47, epsilon: 0.05
# episode: 534: reward: -151.00, mean_100: -143.47, epsilon: 0.05
# episode: 535: reward: -105.00, mean_100: -143.06, epsilon: 0.05
# episode: 536: reward: -143.00, mean_100: -143.59, epsilon: 0.05
# episode: 537: reward: -144.00, mean_100: -143.13, epsilon: 0.05
# episode: 538: reward: -162.00, mean_100: -143.11, epsilon: 0.05
# episode: 539: reward: -108.00, mean_100: -142.73, epsilon: 0.05
# episode: 540: reward: -141.00, mean_100: -142.38, epsilon: 0.05
# episode: 541: reward: -98.00, mean_100: -141.49, epsilon: 0.05
# episode: 542: reward: -145.00, mean_100: -141.20, epsilon: 0.05
# episode: 543: reward: -96.00, mean_100: -140.53, epsilon: 0.05
# episode: 544: reward: -142.00, mean_100: -140.30, epsilon: 0.05
# episode: 545: reward: -151.00, mean_100: -140.38, epsilon: 0.05
# episode: 546: reward: -160.00, mean_100: -141.01, epsilon: 0.05
# episode: 547: reward: -141.00, mean_100: -141.51, epsilon: 0.05
# episode: 548: reward: -153.00, mean_100: -141.04, epsilon: 0.05
# episode: 549: reward: -143.00, mean_100: -141.47, epsilon: 0.05
# episode: 550: reward: -107.00, mean_100: -141.10, epsilon: 0.05
# episode: 551: reward: -120.00, mean_100: -140.50, epsilon: 0.05
# episode: 552: reward: -143.00, mean_100: -141.04, epsilon: 0.05
# episode: 553: reward: -187.00, mean_100: -141.52, epsilon: 0.05
# episode: 554: reward: -147.00, mean_100: -140.99, epsilon: 0.05
# episode: 555: reward: -145.00, mean_100: -141.45, epsilon: 0.05
# episode: 556: reward: -181.00, mean_100: -141.35, epsilon: 0.05
# episode: 557: reward: -101.00, mean_100: -140.92, epsilon: 0.05
# episode: 558: reward: -150.00, mean_100: -141.31, epsilon: 0.05
# episode: 559: reward: -156.00, mean_100: -141.66, epsilon: 0.05
# episode: 560: reward: -152.00, mean_100: -141.22, epsilon: 0.05
# episode: 561: reward: -109.00, mean_100: -140.64, epsilon: 0.05
# episode: 562: reward: -100.00, mean_100: -140.00, epsilon: 0.05
# episode: 563: reward: -154.00, mean_100: -139.78, epsilon: 0.05
# episode: 564: reward: -140.00, mean_100: -139.53, epsilon: 0.05
# episode: 565: reward: -146.00, mean_100: -140.08, epsilon: 0.05
# episode: 566: reward: -146.00, mean_100: -140.25, epsilon: 0.05
# episode: 567: reward: -87.00, mean_100: -139.56, epsilon: 0.05
# episode: 568: reward: -118.00, mean_100: -139.18, epsilon: 0.05
# episode: 569: reward: -150.00, mean_100: -139.01, epsilon: 0.05
# episode: 570: reward: -134.00, mean_100: -138.45, epsilon: 0.05
# episode: 571: reward: -136.00, mean_100: -138.88, epsilon: 0.05
# episode: 572: reward: -141.00, mean_100: -138.73, epsilon: 0.05
# episode: 573: reward: -147.00, mean_100: -138.65, epsilon: 0.05
# episode: 574: reward: -85.00, mean_100: -137.68, epsilon: 0.05
# episode: 575: reward: -157.00, mean_100: -137.64, epsilon: 0.05
# episode: 576: reward: -141.00, mean_100: -137.50, epsilon: 0.05
# episode: 577: reward: -106.00, mean_100: -137.65, epsilon: 0.05
# episode: 578: reward: -137.00, mean_100: -137.45, epsilon: 0.05
# episode: 579: reward: -149.00, mean_100: -137.24, epsilon: 0.05
# episode: 580: reward: -157.00, mean_100: -137.94, epsilon: 0.05
# episode: 581: reward: -90.00, mean_100: -137.26, epsilon: 0.05
# episode: 582: reward: -105.00, mean_100: -136.68, epsilon: 0.05
# episode: 583: reward: -137.00, mean_100: -136.05, epsilon: 0.05
# episode: 584: reward: -137.00, mean_100: -136.53, epsilon: 0.05
# episode: 585: reward: -148.00, mean_100: -136.42, epsilon: 0.05
# episode: 586: reward: -108.00, mean_100: -135.84, epsilon: 0.05
# episode: 587: reward: -143.00, mean_100: -135.71, epsilon: 0.05
# episode: 588: reward: -101.00, mean_100: -135.07, epsilon: 0.05
# episode: 589: reward: -144.00, mean_100: -134.94, epsilon: 0.05
# episode: 590: reward: -144.00, mean_100: -134.71, epsilon: 0.05
# episode: 591: reward: -113.00, mean_100: -134.97, epsilon: 0.05
# episode: 592: reward: -200.00, mean_100: -135.37, epsilon: 0.05
# episode: 593: reward: -140.00, mean_100: -135.36, epsilon: 0.05
# episode: 594: reward: -138.00, mean_100: -135.26, epsilon: 0.05
# episode: 595: reward: -112.00, mean_100: -135.46, epsilon: 0.05
# episode: 596: reward: -145.00, mean_100: -135.30, epsilon: 0.05
# episode: 597: reward: -107.00, mean_100: -134.84, epsilon: 0.05
# episode: 598: reward: -147.00, mean_100: -134.81, epsilon: 0.05
# episode: 599: reward: -133.00, mean_100: -135.26, epsilon: 0.05
# episode: 600: reward: -192.00, mean_100: -135.19, epsilon: 0.05
# episode: 601: reward: -88.00, mean_100: -134.27, epsilon: 0.05
# episode: 602: reward: -140.00, mean_100: -134.80, epsilon: 0.05
# episode: 603: reward: -138.00, mean_100: -134.63, epsilon: 0.05
# episode: 604: reward: -138.00, mean_100: -134.38, epsilon: 0.05
# episode: 605: reward: -176.00, mean_100: -134.54, epsilon: 0.05
# episode: 606: reward: -161.00, mean_100: -134.61, epsilon: 0.05
# episode: 607: reward: -178.00, mean_100: -135.48, epsilon: 0.05
# episode: 608: reward: -140.00, mean_100: -135.36, epsilon: 0.05
# episode: 609: reward: -146.00, mean_100: -135.30, epsilon: 0.05
# episode: 610: reward: -183.00, mean_100: -135.62, epsilon: 0.05
# episode: 611: reward: -111.00, mean_100: -135.16, epsilon: 0.05
# episode: 612: reward: -148.00, mean_100: -135.71, epsilon: 0.05
# episode: 613: reward: -170.00, mean_100: -135.93, epsilon: 0.05
# episode: 614: reward: -144.00, mean_100: -136.43, epsilon: 0.05
# episode: 615: reward: -97.00, mean_100: -135.92, epsilon: 0.05
# episode: 616: reward: -146.00, mean_100: -135.75, epsilon: 0.05
# episode: 617: reward: -111.00, mean_100: -135.39, epsilon: 0.05
# episode: 618: reward: -94.00, mean_100: -134.88, epsilon: 0.05
# episode: 619: reward: -144.00, mean_100: -134.62, epsilon: 0.05
# episode: 620: reward: -150.00, mean_100: -134.55, epsilon: 0.05
# episode: 621: reward: -102.00, mean_100: -134.69, epsilon: 0.05
# episode: 622: reward: -100.00, mean_100: -134.78, epsilon: 0.05
# episode: 623: reward: -150.00, mean_100: -134.78, epsilon: 0.05
# episode: 624: reward: -146.00, mean_100: -135.31, epsilon: 0.05
# episode: 625: reward: -85.00, mean_100: -135.27, epsilon: 0.05
# episode: 626: reward: -88.00, mean_100: -134.47, epsilon: 0.05
# episode: 627: reward: -93.00, mean_100: -133.85, epsilon: 0.05
# episode: 628: reward: -87.00, mean_100: -133.33, epsilon: 0.05
# episode: 629: reward: -143.00, mean_100: -133.87, epsilon: 0.05
# episode: 630: reward: -148.00, mean_100: -134.37, epsilon: 0.05
# episode: 631: reward: -130.00, mean_100: -134.08, epsilon: 0.05
# episode: 632: reward: -152.00, mean_100: -134.15, epsilon: 0.05
# episode: 633: reward: -150.00, mean_100: -134.73, epsilon: 0.05
# episode: 634: reward: -149.00, mean_100: -134.71, epsilon: 0.05
# episode: 635: reward: -151.00, mean_100: -135.17, epsilon: 0.05
# episode: 636: reward: -150.00, mean_100: -135.24, epsilon: 0.05
# episode: 637: reward: -148.00, mean_100: -135.28, epsilon: 0.05
# episode: 638: reward: -146.00, mean_100: -135.12, epsilon: 0.05
# episode: 639: reward: -174.00, mean_100: -135.78, epsilon: 0.05
# episode: 640: reward: -90.00, mean_100: -135.27, epsilon: 0.05
# episode: 641: reward: -153.00, mean_100: -135.82, epsilon: 0.05
# episode: 642: reward: -149.00, mean_100: -135.86, epsilon: 0.05
# episode: 643: reward: -145.00, mean_100: -136.35, epsilon: 0.05
# episode: 644: reward: -92.00, mean_100: -135.85, epsilon: 0.05
# episode: 645: reward: -148.00, mean_100: -135.82, epsilon: 0.05
# episode: 646: reward: -147.00, mean_100: -135.69, epsilon: 0.05
# episode: 647: reward: -103.00, mean_100: -135.31, epsilon: 0.05
# episode: 648: reward: -175.00, mean_100: -135.53, epsilon: 0.05
# episode: 649: reward: -150.00, mean_100: -135.60, epsilon: 0.05
# episode: 650: reward: -97.00, mean_100: -135.50, epsilon: 0.05
# episode: 651: reward: -151.00, mean_100: -135.81, epsilon: 0.05
# episode: 652: reward: -175.00, mean_100: -136.13, epsilon: 0.05
# episode: 653: reward: -89.00, mean_100: -135.15, epsilon: 0.05
# episode: 654: reward: -157.00, mean_100: -135.25, epsilon: 0.05
# episode: 655: reward: -152.00, mean_100: -135.32, epsilon: 0.05
# episode: 656: reward: -195.00, mean_100: -135.46, epsilon: 0.05
# episode: 657: reward: -154.00, mean_100: -135.99, epsilon: 0.05
# episode: 658: reward: -200.00, mean_100: -136.49, epsilon: 0.05
# episode: 659: reward: -93.00, mean_100: -135.86, epsilon: 0.05
# episode: 660: reward: -88.00, mean_100: -135.22, epsilon: 0.05
# episode: 661: reward: -148.00, mean_100: -135.61, epsilon: 0.05
# episode: 662: reward: -142.00, mean_100: -136.03, epsilon: 0.05
# episode: 663: reward: -143.00, mean_100: -135.92, epsilon: 0.05
# episode: 664: reward: -149.00, mean_100: -136.01, epsilon: 0.05
# episode: 665: reward: -150.00, mean_100: -136.05, epsilon: 0.05
# episode: 666: reward: -154.00, mean_100: -136.13, epsilon: 0.05
# episode: 667: reward: -154.00, mean_100: -136.80, epsilon: 0.05
# episode: 668: reward: -115.00, mean_100: -136.77, epsilon: 0.05
# episode: 669: reward: -150.00, mean_100: -136.77, epsilon: 0.05
# episode: 670: reward: -148.00, mean_100: -136.91, epsilon: 0.05
# episode: 671: reward: -149.00, mean_100: -137.04, epsilon: 0.05
# episode: 672: reward: -87.00, mean_100: -136.50, epsilon: 0.05
# episode: 673: reward: -148.00, mean_100: -136.51, epsilon: 0.05
# episode: 674: reward: -151.00, mean_100: -137.17, epsilon: 0.05
# episode: 675: reward: -151.00, mean_100: -137.11, epsilon: 0.05
# episode: 676: reward: -93.00, mean_100: -136.63, epsilon: 0.05
# episode: 677: reward: -103.00, mean_100: -136.60, epsilon: 0.05
# episode: 678: reward: -90.00, mean_100: -136.13, epsilon: 0.05
# episode: 679: reward: -150.00, mean_100: -136.14, epsilon: 0.05
# episode: 680: reward: -147.00, mean_100: -136.04, epsilon: 0.05
# episode: 681: reward: -148.00, mean_100: -136.62, epsilon: 0.05
# episode: 682: reward: -172.00, mean_100: -137.29, epsilon: 0.05
# episode: 683: reward: -148.00, mean_100: -137.40, epsilon: 0.05
# episode: 684: reward: -172.00, mean_100: -137.75, epsilon: 0.05
# episode: 685: reward: -143.00, mean_100: -137.70, epsilon: 0.05
# episode: 686: reward: -92.00, mean_100: -137.54, epsilon: 0.05
# episode: 687: reward: -85.00, mean_100: -136.96, epsilon: 0.05
# episode: 688: reward: -152.00, mean_100: -137.47, epsilon: 0.05
# episode: 689: reward: -101.00, mean_100: -137.04, epsilon: 0.05
# episode: 690: reward: -147.00, mean_100: -137.07, epsilon: 0.05
# episode: 691: reward: -115.00, mean_100: -137.09, epsilon: 0.05
# episode: 692: reward: -150.00, mean_100: -136.59, epsilon: 0.05
# episode: 693: reward: -150.00, mean_100: -136.69, epsilon: 0.05
# episode: 694: reward: -147.00, mean_100: -136.78, epsilon: 0.05
# episode: 695: reward: -152.00, mean_100: -137.18, epsilon: 0.05
# episode: 696: reward: -94.00, mean_100: -136.67, epsilon: 0.05
# episode: 697: reward: -146.00, mean_100: -137.06, epsilon: 0.05
# episode: 698: reward: -88.00, mean_100: -136.47, epsilon: 0.05
# episode: 699: reward: -88.00, mean_100: -136.02, epsilon: 0.05
# episode: 700: reward: -148.00, mean_100: -135.58, epsilon: 0.05
# episode: 701: reward: -175.00, mean_100: -136.45, epsilon: 0.05
# episode: 702: reward: -148.00, mean_100: -136.53, epsilon: 0.05
# episode: 703: reward: -148.00, mean_100: -136.63, epsilon: 0.05
# episode: 704: reward: -200.00, mean_100: -137.25, epsilon: 0.05
# episode: 705: reward: -147.00, mean_100: -136.96, epsilon: 0.05
# episode: 706: reward: -147.00, mean_100: -136.82, epsilon: 0.05
# episode: 707: reward: -149.00, mean_100: -136.53, epsilon: 0.05
# episode: 708: reward: -154.00, mean_100: -136.67, epsilon: 0.05
# episode: 709: reward: -145.00, mean_100: -136.66, epsilon: 0.05
# episode: 710: reward: -179.00, mean_100: -136.62, epsilon: 0.05
# episode: 711: reward: -167.00, mean_100: -137.18, epsilon: 0.05
# episode: 712: reward: -145.00, mean_100: -137.15, epsilon: 0.05
# episode: 713: reward: -147.00, mean_100: -136.92, epsilon: 0.05
# episode: 714: reward: -90.00, mean_100: -136.38, epsilon: 0.05
# episode: 715: reward: -145.00, mean_100: -136.86, epsilon: 0.05
# episode: 716: reward: -84.00, mean_100: -136.24, epsilon: 0.05
# episode: 717: reward: -199.00, mean_100: -137.12, epsilon: 0.05
# episode: 718: reward: -145.00, mean_100: -137.63, epsilon: 0.05
# episode: 719: reward: -146.00, mean_100: -137.65, epsilon: 0.05
# episode: 720: reward: -145.00, mean_100: -137.60, epsilon: 0.05
# episode: 721: reward: -200.00, mean_100: -138.58, epsilon: 0.05
# episode: 722: reward: -148.00, mean_100: -139.06, epsilon: 0.05
# episode: 723: reward: -146.00, mean_100: -139.02, epsilon: 0.05
# episode: 724: reward: -173.00, mean_100: -139.29, epsilon: 0.05
# episode: 725: reward: -175.00, mean_100: -140.19, epsilon: 0.05
# episode: 726: reward: -161.00, mean_100: -140.92, epsilon: 0.05
# episode: 727: reward: -88.00, mean_100: -140.87, epsilon: 0.05
# episode: 728: reward: -145.00, mean_100: -141.45, epsilon: 0.05
# episode: 729: reward: -146.00, mean_100: -141.48, epsilon: 0.05
# episode: 730: reward: -149.00, mean_100: -141.49, epsilon: 0.05
# episode: 731: reward: -147.00, mean_100: -141.66, epsilon: 0.05
# episode: 732: reward: -141.00, mean_100: -141.55, epsilon: 0.05
# episode: 733: reward: -145.00, mean_100: -141.50, epsilon: 0.05
# episode: 734: reward: -92.00, mean_100: -140.93, epsilon: 0.05
# episode: 735: reward: -153.00, mean_100: -140.95, epsilon: 0.05
# episode: 736: reward: -148.00, mean_100: -140.93, epsilon: 0.05
# episode: 737: reward: -88.00, mean_100: -140.33, epsilon: 0.05
# episode: 738: reward: -148.00, mean_100: -140.35, epsilon: 0.05
# episode: 739: reward: -151.00, mean_100: -140.12, epsilon: 0.05
# episode: 740: reward: -150.00, mean_100: -140.72, epsilon: 0.05
# episode: 741: reward: -88.00, mean_100: -140.07, epsilon: 0.05
# episode: 742: reward: -169.00, mean_100: -140.27, epsilon: 0.05
# episode: 743: reward: -98.00, mean_100: -139.80, epsilon: 0.05
# episode: 744: reward: -96.00, mean_100: -139.84, epsilon: 0.05
# episode: 745: reward: -110.00, mean_100: -139.46, epsilon: 0.05
# episode: 746: reward: -148.00, mean_100: -139.47, epsilon: 0.05
# episode: 747: reward: -168.00, mean_100: -140.12, epsilon: 0.05
# episode: 748: reward: -115.00, mean_100: -139.52, epsilon: 0.05
# episode: 749: reward: -96.00, mean_100: -138.98, epsilon: 0.05
# episode: 750: reward: -145.00, mean_100: -139.46, epsilon: 0.05
# episode: 751: reward: -165.00, mean_100: -139.60, epsilon: 0.05
# episode: 752: reward: -161.00, mean_100: -139.46, epsilon: 0.05
# episode: 753: reward: -200.00, mean_100: -140.57, epsilon: 0.05
# episode: 754: reward: -149.00, mean_100: -140.49, epsilon: 0.05
# episode: 755: reward: -149.00, mean_100: -140.46, epsilon: 0.05
# episode: 756: reward: -169.00, mean_100: -140.20, epsilon: 0.05
# episode: 757: reward: -161.00, mean_100: -140.27, epsilon: 0.05
# episode: 758: reward: -148.00, mean_100: -139.75, epsilon: 0.05
# episode: 759: reward: -145.00, mean_100: -140.27, epsilon: 0.05
# episode: 760: reward: -177.00, mean_100: -141.16, epsilon: 0.05
# episode: 761: reward: -84.00, mean_100: -140.52, epsilon: 0.05
# episode: 762: reward: -147.00, mean_100: -140.57, epsilon: 0.05
# episode: 763: reward: -172.00, mean_100: -140.86, epsilon: 0.05
# episode: 764: reward: -146.00, mean_100: -140.83, epsilon: 0.05
# episode: 765: reward: -96.00, mean_100: -140.29, epsilon: 0.05
# episode: 766: reward: -147.00, mean_100: -140.22, epsilon: 0.05
# episode: 767: reward: -156.00, mean_100: -140.24, epsilon: 0.05
# episode: 768: reward: -148.00, mean_100: -140.57, epsilon: 0.05
# episode: 769: reward: -90.00, mean_100: -139.97, epsilon: 0.05
# episode: 770: reward: -148.00, mean_100: -139.97, epsilon: 0.05
# episode: 771: reward: -200.00, mean_100: -140.48, epsilon: 0.05
# episode: 772: reward: -90.00, mean_100: -140.51, epsilon: 0.05
# episode: 773: reward: -148.00, mean_100: -140.51, epsilon: 0.05
# episode: 774: reward: -147.00, mean_100: -140.47, epsilon: 0.05
# episode: 775: reward: -146.00, mean_100: -140.42, epsilon: 0.05
# episode: 776: reward: -147.00, mean_100: -140.96, epsilon: 0.05
# episode: 777: reward: -91.00, mean_100: -140.84, epsilon: 0.05
# episode: 778: reward: -93.00, mean_100: -140.87, epsilon: 0.05
# episode: 779: reward: -149.00, mean_100: -140.86, epsilon: 0.05
# episode: 780: reward: -142.00, mean_100: -140.81, epsilon: 0.05
# episode: 781: reward: -147.00, mean_100: -140.80, epsilon: 0.05
# episode: 782: reward: -150.00, mean_100: -140.58, epsilon: 0.05
# episode: 783: reward: -144.00, mean_100: -140.54, epsilon: 0.05
# episode: 784: reward: -156.00, mean_100: -140.38, epsilon: 0.05
# episode: 785: reward: -168.00, mean_100: -140.63, epsilon: 0.05
# episode: 786: reward: -188.00, mean_100: -141.59, epsilon: 0.05
# episode: 787: reward: -167.00, mean_100: -142.41, epsilon: 0.05
# episode: 788: reward: -146.00, mean_100: -142.35, epsilon: 0.05
# episode: 789: reward: -148.00, mean_100: -142.82, epsilon: 0.05
# episode: 790: reward: -107.00, mean_100: -142.42, epsilon: 0.05
# episode: 791: reward: -144.00, mean_100: -142.71, epsilon: 0.05
# episode: 792: reward: -145.00, mean_100: -142.66, epsilon: 0.05
# episode: 793: reward: -146.00, mean_100: -142.62, epsilon: 0.05
# episode: 794: reward: -146.00, mean_100: -142.61, epsilon: 0.05
# episode: 795: reward: -146.00, mean_100: -142.55, epsilon: 0.05
# episode: 796: reward: -90.00, mean_100: -142.51, epsilon: 0.05
# episode: 797: reward: -111.00, mean_100: -142.16, epsilon: 0.05
# episode: 798: reward: -88.00, mean_100: -142.16, epsilon: 0.05
# episode: 799: reward: -95.00, mean_100: -142.23, epsilon: 0.05
# episode: 800: reward: -148.00, mean_100: -142.23, epsilon: 0.05
# episode: 801: reward: -146.00, mean_100: -141.94, epsilon: 0.05
# episode: 802: reward: -90.00, mean_100: -141.36, epsilon: 0.05
# episode: 803: reward: -196.00, mean_100: -141.84, epsilon: 0.05
# episode: 804: reward: -152.00, mean_100: -141.36, epsilon: 0.05
# episode: 805: reward: -147.00, mean_100: -141.36, epsilon: 0.05
# episode: 806: reward: -173.00, mean_100: -141.62, epsilon: 0.05
# episode: 807: reward: -144.00, mean_100: -141.57, epsilon: 0.05
# episode: 808: reward: -97.00, mean_100: -141.00, epsilon: 0.05
# episode: 809: reward: -144.00, mean_100: -140.99, epsilon: 0.05
# episode: 810: reward: -151.00, mean_100: -140.71, epsilon: 0.05
# episode: 811: reward: -150.00, mean_100: -140.54, epsilon: 0.05
# episode: 812: reward: -151.00, mean_100: -140.60, epsilon: 0.05
# episode: 813: reward: -144.00, mean_100: -140.57, epsilon: 0.05
# episode: 814: reward: -151.00, mean_100: -141.18, epsilon: 0.05
# episode: 815: reward: -150.00, mean_100: -141.23, epsilon: 0.05
# episode: 816: reward: -147.00, mean_100: -141.86, epsilon: 0.05
# episode: 817: reward: -145.00, mean_100: -141.32, epsilon: 0.05
# episode: 818: reward: -148.00, mean_100: -141.35, epsilon: 0.05
# episode: 819: reward: -147.00, mean_100: -141.36, epsilon: 0.05
# episode: 820: reward: -149.00, mean_100: -141.40, epsilon: 0.05
# episode: 821: reward: -94.00, mean_100: -140.34, epsilon: 0.05
# episode: 822: reward: -143.00, mean_100: -140.29, epsilon: 0.05
# episode: 823: reward: -149.00, mean_100: -140.32, epsilon: 0.05
# episode: 824: reward: -146.00, mean_100: -140.05, epsilon: 0.05
# episode: 825: reward: -144.00, mean_100: -139.74, epsilon: 0.05
# episode: 826: reward: -151.00, mean_100: -139.64, epsilon: 0.05
# episode: 827: reward: -146.00, mean_100: -140.22, epsilon: 0.05
# episode: 828: reward: -151.00, mean_100: -140.28, epsilon: 0.05
# episode: 829: reward: -91.00, mean_100: -139.73, epsilon: 0.05
# episode: 830: reward: -151.00, mean_100: -139.75, epsilon: 0.05
# episode: 831: reward: -147.00, mean_100: -139.75, epsilon: 0.05
# episode: 832: reward: -145.00, mean_100: -139.79, epsilon: 0.05
# episode: 833: reward: -200.00, mean_100: -140.34, epsilon: 0.05
# episode: 834: reward: -87.00, mean_100: -140.29, epsilon: 0.05
# episode: 835: reward: -119.00, mean_100: -139.95, epsilon: 0.05
# episode: 836: reward: -150.00, mean_100: -139.97, epsilon: 0.05
# episode: 837: reward: -86.00, mean_100: -139.95, epsilon: 0.05
# episode: 838: reward: -152.00, mean_100: -139.99, epsilon: 0.05
# episode: 839: reward: -144.00, mean_100: -139.92, epsilon: 0.05
# episode: 840: reward: -149.00, mean_100: -139.91, epsilon: 0.05
# episode: 841: reward: -143.00, mean_100: -140.46, epsilon: 0.05
# episode: 842: reward: -93.00, mean_100: -139.70, epsilon: 0.05
# episode: 843: reward: -143.00, mean_100: -140.15, epsilon: 0.05
# episode: 844: reward: -158.00, mean_100: -140.77, epsilon: 0.05
# episode: 845: reward: -92.00, mean_100: -140.59, epsilon: 0.05
# episode: 846: reward: -148.00, mean_100: -140.59, epsilon: 0.05
# episode: 847: reward: -157.00, mean_100: -140.48, epsilon: 0.05
# episode: 848: reward: -106.00, mean_100: -140.39, epsilon: 0.05
# episode: 849: reward: -143.00, mean_100: -140.86, epsilon: 0.05
# episode: 850: reward: -97.00, mean_100: -140.38, epsilon: 0.05
# episode: 851: reward: -143.00, mean_100: -140.16, epsilon: 0.05
# episode: 852: reward: -173.00, mean_100: -140.28, epsilon: 0.05
# episode: 853: reward: -90.00, mean_100: -139.18, epsilon: 0.05
# episode: 854: reward: -153.00, mean_100: -139.22, epsilon: 0.05
# episode: 855: reward: -153.00, mean_100: -139.26, epsilon: 0.05
# episode: 856: reward: -88.00, mean_100: -138.45, epsilon: 0.05
# episode: 857: reward: -200.00, mean_100: -138.84, epsilon: 0.05
# episode: 858: reward: -185.00, mean_100: -139.21, epsilon: 0.05
# episode: 859: reward: -148.00, mean_100: -139.24, epsilon: 0.05
# episode: 860: reward: -94.00, mean_100: -138.41, epsilon: 0.05
# episode: 861: reward: -87.00, mean_100: -138.44, epsilon: 0.05
# episode: 862: reward: -182.00, mean_100: -138.79, epsilon: 0.05
# episode: 863: reward: -166.00, mean_100: -138.73, epsilon: 0.05
# episode: 864: reward: -88.00, mean_100: -138.15, epsilon: 0.05
# episode: 865: reward: -171.00, mean_100: -138.90, epsilon: 0.05
# episode: 866: reward: -94.00, mean_100: -138.37, epsilon: 0.05
# episode: 867: reward: -181.00, mean_100: -138.62, epsilon: 0.05
# episode: 868: reward: -149.00, mean_100: -138.63, epsilon: 0.05
# episode: 869: reward: -176.00, mean_100: -139.49, epsilon: 0.05
# episode: 870: reward: -93.00, mean_100: -138.94, epsilon: 0.05
# episode: 871: reward: -148.00, mean_100: -138.42, epsilon: 0.05
# episode: 872: reward: -173.00, mean_100: -139.25, epsilon: 0.05
# episode: 873: reward: -149.00, mean_100: -139.26, epsilon: 0.05
# episode: 874: reward: -88.00, mean_100: -138.67, epsilon: 0.05
# episode: 875: reward: -89.00, mean_100: -138.10, epsilon: 0.05
# episode: 876: reward: -171.00, mean_100: -138.34, epsilon: 0.05
# episode: 877: reward: -152.00, mean_100: -138.95, epsilon: 0.05
# episode: 878: reward: -156.00, mean_100: -139.58, epsilon: 0.05
# episode: 879: reward: -169.00, mean_100: -139.78, epsilon: 0.05
# episode: 880: reward: -95.00, mean_100: -139.31, epsilon: 0.05
# episode: 881: reward: -190.00, mean_100: -139.74, epsilon: 0.05
# episode: 882: reward: -200.00, mean_100: -140.24, epsilon: 0.05
# episode: 883: reward: -133.00, mean_100: -140.13, epsilon: 0.05
# episode: 884: reward: -84.00, mean_100: -139.41, epsilon: 0.05
# episode: 885: reward: -178.00, mean_100: -139.51, epsilon: 0.05
# episode: 886: reward: -137.00, mean_100: -139.00, epsilon: 0.05
# episode: 887: reward: -142.00, mean_100: -138.75, epsilon: 0.05
# episode: 888: reward: -157.00, mean_100: -138.86, epsilon: 0.05
# episode: 889: reward: -103.00, mean_100: -138.41, epsilon: 0.05
# episode: 890: reward: -191.00, mean_100: -139.25, epsilon: 0.05
# episode: 891: reward: -150.00, mean_100: -139.31, epsilon: 0.05
# episode: 892: reward: -125.00, mean_100: -139.11, epsilon: 0.05
# episode: 893: reward: -163.00, mean_100: -139.28, epsilon: 0.05
# episode: 894: reward: -200.00, mean_100: -139.82, epsilon: 0.05
# episode: 895: reward: -145.00, mean_100: -139.81, epsilon: 0.05
# episode: 896: reward: -172.00, mean_100: -140.63, epsilon: 0.05
# episode: 897: reward: -190.00, mean_100: -141.42, epsilon: 0.05
# episode: 898: reward: -130.00, mean_100: -141.84, epsilon: 0.05
# episode: 899: reward: -88.00, mean_100: -141.77, epsilon: 0.05
# episode: 900: reward: -136.00, mean_100: -141.65, epsilon: 0.05
# episode: 901: reward: -142.00, mean_100: -141.61, epsilon: 0.05
# episode: 902: reward: -180.00, mean_100: -142.51, epsilon: 0.05
# episode: 903: reward: -136.00, mean_100: -141.91, epsilon: 0.05
# episode: 904: reward: -92.00, mean_100: -141.31, epsilon: 0.05
# episode: 905: reward: -188.00, mean_100: -141.72, epsilon: 0.05
# episode: 906: reward: -94.00, mean_100: -140.93, epsilon: 0.05
# episode: 907: reward: -139.00, mean_100: -140.88, epsilon: 0.05
# episode: 908: reward: -163.00, mean_100: -141.54, epsilon: 0.05
# episode: 909: reward: -91.00, mean_100: -141.01, epsilon: 0.05
# episode: 910: reward: -86.00, mean_100: -140.36, epsilon: 0.05
# episode: 911: reward: -143.00, mean_100: -140.29, epsilon: 0.05
# episode: 912: reward: -193.00, mean_100: -140.71, epsilon: 0.05
# episode: 913: reward: -185.00, mean_100: -141.12, epsilon: 0.05
# episode: 914: reward: -157.00, mean_100: -141.18, epsilon: 0.05
# episode: 915: reward: -91.00, mean_100: -140.59, epsilon: 0.05
# episode: 916: reward: -137.00, mean_100: -140.49, epsilon: 0.05
# episode: 917: reward: -143.00, mean_100: -140.47, epsilon: 0.05
# episode: 918: reward: -187.00, mean_100: -140.86, epsilon: 0.05
# episode: 919: reward: -148.00, mean_100: -140.87, epsilon: 0.05
# episode: 920: reward: -94.00, mean_100: -140.32, epsilon: 0.05
# episode: 921: reward: -113.00, mean_100: -140.51, epsilon: 0.05
# episode: 922: reward: -94.00, mean_100: -140.02, epsilon: 0.05
# episode: 923: reward: -147.00, mean_100: -140.00, epsilon: 0.05
# episode: 924: reward: -200.00, mean_100: -140.54, epsilon: 0.05
# episode: 925: reward: -105.00, mean_100: -140.15, epsilon: 0.05
# episode: 926: reward: -138.00, mean_100: -140.02, epsilon: 0.05
# episode: 927: reward: -142.00, mean_100: -139.98, epsilon: 0.05
# episode: 928: reward: -160.00, mean_100: -140.07, epsilon: 0.05
# episode: 929: reward: -199.00, mean_100: -141.15, epsilon: 0.05
# episode: 930: reward: -163.00, mean_100: -141.27, epsilon: 0.05
# episode: 931: reward: -169.00, mean_100: -141.49, epsilon: 0.05
# episode: 932: reward: -200.00, mean_100: -142.04, epsilon: 0.05
# episode: 933: reward: -190.00, mean_100: -141.94, epsilon: 0.05
# episode: 934: reward: -142.00, mean_100: -142.49, epsilon: 0.05
# episode: 935: reward: -179.00, mean_100: -143.09, epsilon: 0.05
# episode: 936: reward: -138.00, mean_100: -142.97, epsilon: 0.05
# episode: 937: reward: -144.00, mean_100: -143.55, epsilon: 0.05
# episode: 938: reward: -168.00, mean_100: -143.71, epsilon: 0.05
# episode: 939: reward: -200.00, mean_100: -144.27, epsilon: 0.05
# episode: 940: reward: -151.00, mean_100: -144.29, epsilon: 0.05
# episode: 941: reward: -167.00, mean_100: -144.53, epsilon: 0.05
# episode: 942: reward: -171.00, mean_100: -145.31, epsilon: 0.05
# episode: 943: reward: -137.00, mean_100: -145.25, epsilon: 0.05
# episode: 944: reward: -177.00, mean_100: -145.44, epsilon: 0.05
# episode: 945: reward: -144.00, mean_100: -145.96, epsilon: 0.05
# episode: 946: reward: -114.00, mean_100: -145.62, epsilon: 0.05
# episode: 947: reward: -142.00, mean_100: -145.47, epsilon: 0.05
# episode: 948: reward: -146.00, mean_100: -145.87, epsilon: 0.05
# episode: 949: reward: -136.00, mean_100: -145.80, epsilon: 0.05
# episode: 950: reward: -96.00, mean_100: -145.79, epsilon: 0.05
# episode: 951: reward: -106.00, mean_100: -145.42, epsilon: 0.05
# episode: 952: reward: -138.00, mean_100: -145.07, epsilon: 0.05
# episode: 953: reward: -177.00, mean_100: -145.94, epsilon: 0.05
# episode: 954: reward: -138.00, mean_100: -145.79, epsilon: 0.05
# episode: 955: reward: -93.00, mean_100: -145.19, epsilon: 0.05
# episode: 956: reward: -144.00, mean_100: -145.75, epsilon: 0.05
# episode: 957: reward: -151.00, mean_100: -145.26, epsilon: 0.05
# episode: 958: reward: -174.00, mean_100: -145.15, epsilon: 0.05
# episode: 959: reward: -182.00, mean_100: -145.49, epsilon: 0.05
# episode: 960: reward: -146.00, mean_100: -146.01, epsilon: 0.05
# episode: 961: reward: -143.00, mean_100: -146.57, epsilon: 0.05
# episode: 962: reward: -138.00, mean_100: -146.13, epsilon: 0.05
# episode: 963: reward: -105.00, mean_100: -145.52, epsilon: 0.05
# episode: 964: reward: -94.00, mean_100: -145.58, epsilon: 0.05
# episode: 965: reward: -99.00, mean_100: -144.86, epsilon: 0.05
# episode: 966: reward: -135.00, mean_100: -145.27, epsilon: 0.05
# episode: 967: reward: -141.00, mean_100: -144.87, epsilon: 0.05
# episode: 968: reward: -140.00, mean_100: -144.78, epsilon: 0.05
# episode: 969: reward: -98.00, mean_100: -144.00, epsilon: 0.05
# episode: 970: reward: -137.00, mean_100: -144.44, epsilon: 0.05
# episode: 971: reward: -139.00, mean_100: -144.35, epsilon: 0.05
# episode: 972: reward: -137.00, mean_100: -143.99, epsilon: 0.05
# episode: 973: reward: -138.00, mean_100: -143.88, epsilon: 0.05
# episode: 974: reward: -142.00, mean_100: -144.42, epsilon: 0.05
# episode: 975: reward: -139.00, mean_100: -144.92, epsilon: 0.05
# episode: 976: reward: -91.00, mean_100: -144.12, epsilon: 0.05
# episode: 977: reward: -143.00, mean_100: -144.03, epsilon: 0.05
# episode: 978: reward: -84.00, mean_100: -143.31, epsilon: 0.05
# episode: 979: reward: -171.00, mean_100: -143.33, epsilon: 0.05
# episode: 980: reward: -113.00, mean_100: -143.51, epsilon: 0.05
# episode: 981: reward: -147.00, mean_100: -143.08, epsilon: 0.05
# episode: 982: reward: -138.00, mean_100: -142.46, epsilon: 0.05
# episode: 983: reward: -92.00, mean_100: -142.05, epsilon: 0.05
# episode: 984: reward: -84.00, mean_100: -142.05, epsilon: 0.05
# episode: 985: reward: -200.00, mean_100: -142.27, epsilon: 0.05
# episode: 986: reward: -144.00, mean_100: -142.34, epsilon: 0.05
# episode: 987: reward: -138.00, mean_100: -142.30, epsilon: 0.05
# episode: 988: reward: -144.00, mean_100: -142.17, epsilon: 0.05
# episode: 989: reward: -141.00, mean_100: -142.55, epsilon: 0.05
# episode: 990: reward: -149.00, mean_100: -142.13, epsilon: 0.05
# episode: 991: reward: -144.00, mean_100: -142.07, epsilon: 0.05
# episode: 992: reward: -109.00, mean_100: -141.91, epsilon: 0.05
# episode: 993: reward: -141.00, mean_100: -141.69, epsilon: 0.05
# episode: 994: reward: -142.00, mean_100: -141.11, epsilon: 0.05
# episode: 995: reward: -94.00, mean_100: -140.60, epsilon: 0.05
# episode: 996: reward: -86.00, mean_100: -139.74, epsilon: 0.05
# episode: 997: reward: -142.00, mean_100: -139.26, epsilon: 0.05
# episode: 998: reward: -87.00, mean_100: -138.83, epsilon: 0.05
# episode: 999: reward: -146.00, mean_100: -139.41, epsilon: 0.05
